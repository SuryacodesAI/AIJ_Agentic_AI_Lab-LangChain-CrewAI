# %%
# !pip install -U langchain langchain-openai langchain-experimental openai pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.1/210.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 143.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 108.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 45.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ...

# %%
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from langchain_openai import ChatOpenAI
from langchain_experimental.agents import create_pandas_dataframe_agent

# %%
import pandas as pd

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
import pandas as pd

df = pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# %%
agent = create_pandas_dataframe_agent(
    llm,
    df,
    verbose=True,
    allow_dangerous_code=True
)

# %%
agent.run("What percentage of passengers survived?")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-777720350.py in <cell line: 0>()
# ----> 1 agent.run("What percentage of passengers survived?")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     204                 warned = True
#     205                 emit_warning()
# --> 206             return wrapped(*args, **kwargs)
#     207
#     208         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     630                 msg = "`run` supports only one positional argument."
#     631                 raise ValueError(msg)
# ...

# %%
agent.run("What is the average age of passengers?")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-873852733.py in <cell line: 0>()
# ----> 1 agent.run("What is the average age of passengers?")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     204                 warned = True
#     205                 emit_warning()
# --> 206             return wrapped(*args, **kwargs)
#     207
#     208         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     630                 msg = "`run` supports only one positional argument."
#     631                 raise ValueError(msg)
# ...
